# %%
from phantoms.utils.CKA.cka_plots import plot_alignment_metric_errorbars, aggregate_alignment_metric, plot_aggregated_alignment_by_group

# %%
layer_names = ['gnn_1_head_1_mean',
'gnn_1_head_2_mean',
'gnn_1_head_3_mean',
'gnn_1_head_4_mean',
'gnn_2_head_1_mean',
'gnn_2_head_2_mean',
'gnn_2_head_3_mean',
'gnn_2_head_4_mean',
'gnn_3_head_1_mean',
'gnn_3_head_2_mean',
'gnn_3_head_3_mean',
'gnn_3_head_4_mean',
'encoder_projection',
'decoder_layer_1_head_1',
'decoder_layer_1_head_2',
'decoder_layer_1_head_3',
'decoder_layer_1_head_4',
'decoder_layer_2_head_1',
'decoder_layer_2_head_2',
'decoder_layer_2_head_3',
'decoder_layer_2_head_4',
'decoder_layer_3_head_1',
'decoder_layer_3_head_2',
'decoder_layer_3_head_3',
'decoder_layer_3_head_4',
'decoder_layer_4_head_1',
'decoder_layer_4_head_2',
'decoder_layer_4_head_3',
'decoder_layer_4_head_4']

# %% [markdown]
# ## DreaMS

# %%
experiment_dreams = [
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_LUMI_cut_tree_0_2025-02-24_20-38-02/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_LUMI_cut_tree_1_2025-02-24_21-19-10/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_LUMI_cut_tree_2_2025-02-24_22-04-40/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_LUMI_cut_tree_3_2025-02-24_22-51-08/embeddings'
]

# %%
agg_metrics_dreams = aggregate_alignment_metric(experiment_dreams, layer_names, top_k=20, center=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 agg_metrics_dreams = aggregate_alignment_metric(experiment_dreams, layer_names, top_k=20, center=True)
#
# File ~/CODE/PhantoMS/phantoms/utils/CKA/cka_processing.py:350, in aggregate_alignment_metric(exp_dirs, layer_names, top_k, center)
#     348             X = emb1[layer]  # shape: [num_examples, dim]
#     349             Y = emb2[layer]
# --> 350             metric = compute_alignment_metric(X, Y, top_k=top_k, center=center)
#     351             agg_dict[layer].append(metric)
#     353 for layer in agg_dict:
#
# File ~/CODE/PhantoMS/phantoms/utils/CKA/cka_processing.py:318, in compute_alignment_metric(X, Y, top_k, center)
#     304 def compute_alignment_metric(X, Y, top_k=5, center=True):
#     305     """
#     306     Computes an aggregate alignment metric between representations X and Y for a given layer.
#     307     It performs shared subspace analysis and returns the average cosine similarity over the top_k eigenvectors.
#    (...)
#     316         float: Average cosine similarity over the top_k eigenvectors.
#     317     """
# --> 318     eigvals, proj_norms, cosines = shared_subspace_analysis(X, Y, center=center)
#     319     top_cos = cosines[:min(top_k, len(cosines))]
#     320     return np.mean(top_cos)
#
# File ~/CODE/PhantoMS/phantoms/utils/CKA/cka_processing.py:80, in shared_subspace_analysis(X, Y, center)
#      77 S_Y = np.dot(Y_centered, Y_centered.T)
#      79 # Eigen-decomposition of S_X (since it is symmetric)
# ---> 80 eigvals, U = np.linalg.eigh(S_X)
#      82 # Sort eigenvalues (and eigenvectors) in descending order:
#      83 sorted_indices = np.argsort(eigvals)[::-1]
#
# File ~/UTILS/anaconda3/envs/phantoms_env/lib/python3.11/site-packages/numpy/linalg/_linalg.py:1601, in eigh(a, UPLO)
#    1597 signature = 'D->dD' if isComplexType(t) else 'd->dd'
#    1598 with errstate(call=_raise_linalgerror_eigenvalues_nonconvergence,
#    1599               invalid='call', over='ignore', divide='ignore',
#    1600               under='ignore'):
# -> 1601     w, vt = gufunc(a, signature=signature)
#    1602 w = w.astype(_realType(result_t), copy=False)
#    1603 vt = vt.astype(result_t, copy=False)
#
# KeyboardInterrupt:

# %%
plot_alignment_metric_errorbars(agg_metrics_dreams, layer_names,
    xlabel="Layer", ylabel="Average Cosine Similarity (Top 5)")

# %% [markdown]
# ## DreaMS Bonus

# %%
experiment_dreams_bonus = [
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_bonus_LUMI_cut_tree_0_2025-02-24_23-36-43/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_bonus_LUMI_cut_tree_1_2025-02-25_00-45-36/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_bonus_LUMI_cut_tree_2_2025-02-25_09-38-22/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_bonus_LUMI_cut_tree_3_2025-02-25_10-29-19/embeddings'
]

# %%
agg_metrics_dreams_bonus = aggregate_alignment_metric(experiment_dreams_bonus, layer_names, top_k=20, center=True)

# %%
plot_alignment_metric_errorbars(agg_metrics_dreams_bonus, layer_names,
    xlabel="Layer", ylabel="Average Cosine Similarity (Top 5)")

# %% [markdown]
# ## Raw Spectra

# %%
experiment_raw_spectra = [
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_LUMI_cut_tree_0_2025-02-23_20-12-43/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_LUMI_cut_tree_1_2025-02-24_10-54-10/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_LUMI_cut_tree_2_2025-02-24_11-36-59/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_LUMI_cut_tree_3_2025-02-24_12-21-38/embeddings'
]

# %%
agg_metrics_raw_spectra = aggregate_alignment_metric(experiment_raw_spectra, layer_names, top_k=20, center=True)

# %%
plot_alignment_metric_errorbars(agg_metrics_raw_spectra , layer_names,
    xlabel="Layer", ylabel="Average Cosine Similarity (Top 5)")

# %% [markdown]
# ## Raw Spectra Bonus

# %%
experiment_raw_spectra_bonus = [
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_bonus_LUMI_cut_tree_0_2025-02-24_13-05-24/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_bonus_LUMI_cut_tree_1_2025-02-24_16-36-24/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_bonus_LUMI_cut_tree_2_2025-02-24_18-58-55/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_bonus_LUMI_cut_tree_3_2025-02-24_19-47-54/embeddings'
]

# %%
agg_metrics_raw_spectra_bonus = aggregate_alignment_metric(experiment_raw_spectra_bonus, layer_names, top_k=20, center=True)

# %%
plot_alignment_metric_errorbars(agg_metrics_raw_spectra_bonus , layer_names,
    xlabel="Layer", ylabel="Average Cosine Similarity (Top 5)")

# %% [markdown]
# # AGGREGATE

# %%
experiment_types = {
    "dreams": experiment_dreams,             
    "dreams_bonus": experiment_dreams_bonus,    
    "raw_spectra": experiment_raw_spectra,         
    "raw_spectra_bonus": experiment_raw_spectra_bonus  
}

# %%
plot_aggregated_alignment_by_group(experiment_types, layer_names, top_k=30, center=True)

# %% [markdown]
# # By Level

# %% [markdown]
# ## level 2

# %%
experiment_level_2 = [
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_LUMI_cut_tree_0_2025-02-24_20-38-02/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_bonus_LUMI_cut_tree_0_2025-02-24_23-36-43/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_LUMI_cut_tree_0_2025-02-23_20-12-43/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_bonus_LUMI_cut_tree_0_2025-02-24_13-05-24/embeddings',
]

# %%
agg_metrics_level_2 = aggregate_alignment_metric(experiment_level_2, layer_names, top_k=20, center=True)

# %%
plot_alignment_metric_errorbars(agg_metrics_level_2 , layer_names,
    xlabel="Layer", ylabel="Average Cosine Similarity (Top 5)")

# %% [markdown]
# ## level 3

# %%
experiment_level_3 = [
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_LUMI_cut_tree_1_2025-02-24_21-19-10/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_bonus_LUMI_cut_tree_1_2025-02-25_00-45-36/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_LUMI_cut_tree_1_2025-02-24_10-54-10/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_bonus_LUMI_cut_tree_1_2025-02-24_16-36-24/embeddings'
]

# %%
agg_metrics_level_3 = aggregate_alignment_metric(experiment_level_3, layer_names, top_k=20, center=True)

# %%
plot_alignment_metric_errorbars(agg_metrics_level_3 , layer_names,
    xlabel="Layer", ylabel="Average Cosine Similarity (Top 5)")

# %% [markdown]
# # level 4

# %%
experiment_level_4 = [
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_LUMI_cut_tree_2_2025-02-24_22-04-40/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_bonus_LUMI_cut_tree_2_2025-02-25_09-38-22/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_LUMI_cut_tree_2_2025-02-24_11-36-59/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_bonus_LUMI_cut_tree_2_2025-02-24_18-58-55/embeddings'
]

# %%
agg_metrics_level_4 = aggregate_alignment_metric(experiment_level_4, layer_names, top_k=20, center=True)

# %%
plot_alignment_metric_errorbars(agg_metrics_level_4 , layer_names,
    xlabel="Layer", ylabel="Average Cosine Similarity (Top 5)")

# %% [markdown]
# ## level 5

# %%
experiment_level_5 = [
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_LUMI_cut_tree_3_2025-02-24_22-51-08/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_bonus_LUMI_cut_tree_3_2025-02-25_10-29-19/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_LUMI_cut_tree_3_2025-02-24_12-21-38/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_bonus_LUMI_cut_tree_3_2025-02-24_19-47-54/embeddings',
]

# %%
agg_metrics_level_5 = aggregate_alignment_metric(experiment_level_5, layer_names, top_k=20, center=True)

# %%
plot_alignment_metric_errorbars(agg_metrics_level_5 , layer_names,
    xlabel="Layer", ylabel="Average Cosine Similarity (Top 5)")

# %% [markdown]
# ## AGGREGATE

# %%
experiment_levels = {
    "ms2": experiment_level_2,  
    "ms3": experiment_level_3,
    "ms4": experiment_level_4,
    "ms5": experiment_level_5
}

# %%
plot_aggregated_alignment_by_group(experiment_levels, layer_names, top_k=20, center=True)
