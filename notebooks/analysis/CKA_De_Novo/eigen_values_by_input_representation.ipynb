# %%
import os
import re

from phantoms.utils.CKA.cka_plots import plot_effective_rank_vs_layer_multi, plot_avg_cum_explained_variance_multi, plot_aggregated_metrics_by_type

# %%
def extract_label(exp_dir):
    match = re.search(r'cut_tree_\d+', exp_dir)
    if match:
        return match.group(0)
    return os.path.basename(exp_dir)

def same_depth_label(exp_dir):
    exp_folder = os.path.basename(os.path.dirname(exp_dir)).lower()
    
    if "dreams" in exp_folder:
        label = "dreams_embeddings"
    else:
        label = "raw_spectra"
    
    if "bonus" in exp_folder:
        label += "_formula"

    return label

# %%
layer_names = ['gnn_1_head_1_mean',
'gnn_1_head_2_mean',
'gnn_1_head_3_mean',
'gnn_1_head_4_mean',
'gnn_2_head_1_mean',
'gnn_2_head_2_mean',
'gnn_2_head_3_mean',
'gnn_2_head_4_mean',
'gnn_3_head_1_mean',
'gnn_3_head_2_mean',
'gnn_3_head_3_mean',
'gnn_3_head_4_mean',
'encoder_projection',
'decoder_layer_1_head_1',
'decoder_layer_1_head_2',
'decoder_layer_1_head_3',
'decoder_layer_1_head_4',
'decoder_layer_2_head_1',
'decoder_layer_2_head_2',
'decoder_layer_2_head_3',
'decoder_layer_2_head_4',
'decoder_layer_3_head_1',
'decoder_layer_3_head_2',
'decoder_layer_3_head_3',
'decoder_layer_3_head_4',
'decoder_layer_4_head_1',
'decoder_layer_4_head_2',
'decoder_layer_4_head_3',
'decoder_layer_4_head_4']

# %% [markdown]
# ## DreaMS

# %%
experiment_dreams = [
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_LUMI_cut_tree_0_2025-02-24_20-38-02/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_LUMI_cut_tree_1_2025-02-24_21-19-10/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_LUMI_cut_tree_2_2025-02-24_22-04-40/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_LUMI_cut_tree_3_2025-02-24_22-51-08/embeddings'
]

# %%
plot_effective_rank_vs_layer_multi(experiment_dreams, layer_names, model_label_func=extract_label)

# %%
plot_avg_cum_explained_variance_multi(experiment_dreams, layer_names, max_components=100, center=True, model_label_func=extract_label)
# Out:
# Processing experiments: 100%|██████████| 4/4 [00:02<00:00,  1.68it/s]

# %% [markdown]
# ## DreaMS Bonus

# %%
experiment_dreams_bonus = [
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_bonus_LUMI_cut_tree_0_2025-02-24_23-36-43/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_bonus_LUMI_cut_tree_1_2025-02-25_00-45-36/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_bonus_LUMI_cut_tree_2_2025-02-25_09-38-22/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_bonus_LUMI_cut_tree_3_2025-02-25_10-29-19/embeddings'
]

# %%
plot_effective_rank_vs_layer_multi(experiment_dreams_bonus, layer_names, model_label_func=extract_label)

# %%
plot_avg_cum_explained_variance_multi(experiment_dreams_bonus, layer_names, max_components=100, center=True, model_label_func=extract_label)
# Out:
# Processing experiments: 100%|██████████| 4/4 [00:02<00:00,  1.90it/s]

# %% [markdown]
# ## Raw Spectra

# %%
experiment_raw_spectra = [
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_LUMI_cut_tree_0_2025-02-23_20-12-43/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_LUMI_cut_tree_1_2025-02-24_10-54-10/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_LUMI_cut_tree_2_2025-02-24_11-36-59/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_LUMI_cut_tree_3_2025-02-24_12-21-38/embeddings'
]

# %%
plot_effective_rank_vs_layer_multi(experiment_raw_spectra, layer_names, model_label_func=extract_label)

# %%
plot_avg_cum_explained_variance_multi(experiment_raw_spectra, layer_names, max_components=100, center=True, model_label_func=extract_label)
# Out:
# Processing experiments: 100%|██████████| 4/4 [00:01<00:00,  2.08it/s]

# %% [markdown]
# ## Raw Spectra Bonus

# %%
experiment_raw_spectra_bonus = [
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_bonus_LUMI_cut_tree_0_2025-02-24_13-05-24/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_bonus_LUMI_cut_tree_1_2025-02-24_16-36-24/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_bonus_LUMI_cut_tree_2_2025-02-24_18-58-55/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_bonus_LUMI_cut_tree_3_2025-02-24_19-47-54/embeddings'
]

# %%
plot_effective_rank_vs_layer_multi(experiment_raw_spectra_bonus, layer_names, model_label_func=extract_label)

# %%
plot_avg_cum_explained_variance_multi(experiment_raw_spectra_bonus, layer_names, max_components=100, center=True, model_label_func=extract_label)
# Out:
# Processing experiments: 100%|██████████| 4/4 [00:01<00:00,  2.06it/s]

# %% [markdown]
# # AGGREGATE

# %%
experiment_types = {
    "dreams": experiment_dreams,             
    "dreams_bonus": experiment_dreams_bonus,    
    "raw_spectra": experiment_raw_spectra,         
    "raw_spectra_bonus": experiment_raw_spectra_bonus  
}

# %%
# Then, to plot aggregated effective rank:
plot_aggregated_metrics_by_type(experiment_types, layer_names, metric="effective_rank")

# %%
# And for cumulative explained variance:
plot_aggregated_metrics_by_type(experiment_types, layer_names, max_components=100, center=True, metric="cum_explained")

# %% [markdown]
# # By Level

# %% [markdown]
# ## level 2

# %%
experiment_level_2 = [
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_LUMI_cut_tree_0_2025-02-24_20-38-02/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_bonus_LUMI_cut_tree_0_2025-02-24_23-36-43/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_LUMI_cut_tree_0_2025-02-23_20-12-43/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_bonus_LUMI_cut_tree_0_2025-02-24_13-05-24/embeddings',
]

# %%
plot_effective_rank_vs_layer_multi(experiment_level_2, layer_names, model_label_func=same_depth_label)

# %%
plot_avg_cum_explained_variance_multi(experiment_level_2, layer_names, max_components=100, center=True, model_label_func=same_depth_label)
# Out:
# Processing experiments: 100%|██████████| 4/4 [00:02<00:00,  1.90it/s]

# %% [markdown]
# ## level 3

# %%
experiment_level_3 = [
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_LUMI_cut_tree_1_2025-02-24_21-19-10/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_bonus_LUMI_cut_tree_1_2025-02-25_00-45-36/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_LUMI_cut_tree_1_2025-02-24_10-54-10/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_bonus_LUMI_cut_tree_1_2025-02-24_16-36-24/embeddings'
]

# %%
plot_effective_rank_vs_layer_multi(experiment_level_3, layer_names, model_label_func=same_depth_label)

# %%
plot_avg_cum_explained_variance_multi(experiment_level_3, layer_names, max_components=100, center=True, model_label_func=same_depth_label)
# Out:
# Processing experiments: 100%|██████████| 4/4 [00:01<00:00,  2.03it/s]

# %% [markdown]
# ## level 4

# %%
experiment_level_4 = [
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_LUMI_cut_tree_2_2025-02-24_22-04-40/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_bonus_LUMI_cut_tree_2_2025-02-25_09-38-22/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_LUMI_cut_tree_2_2025-02-24_11-36-59/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_bonus_LUMI_cut_tree_2_2025-02-24_18-58-55/embeddings'
]

# %%
plot_effective_rank_vs_layer_multi(experiment_level_4, layer_names, model_label_func=same_depth_label)

# %%
plot_avg_cum_explained_variance_multi(experiment_level_4, layer_names, max_components=100, center=True, model_label_func=same_depth_label)
# Out:
# Processing experiments: 100%|██████████| 4/4 [00:02<00:00,  1.98it/s]

# %% [markdown]
# ## level 5

# %%
experiment_level_5 = [
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_LUMI_cut_tree_3_2025-02-24_22-51-08/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_dreams_bonus_LUMI_cut_tree_3_2025-02-25_10-29-19/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_LUMI_cut_tree_3_2025-02-24_12-21-38/embeddings',
    '/Users/macbook/CODE/PhantoMS/data/de_novo_trained/cut_tree_transformer/config_denovo_spectra_bonus_LUMI_cut_tree_3_2025-02-24_19-47-54/embeddings',
]

# %%
plot_effective_rank_vs_layer_multi(experiment_level_5, layer_names, model_label_func=same_depth_label)

# %%
plot_avg_cum_explained_variance_multi(experiment_level_5, layer_names, max_components=100, center=True, model_label_func=same_depth_label)
# Out:
# Processing experiments: 100%|██████████| 4/4 [00:02<00:00,  1.94it/s]

# %% [markdown]
# ## AGGREGATE

# %%
experiment_levels = {
    "ms2": experiment_level_2,  
    "ms3": experiment_level_3,
    "ms4": experiment_level_4,
    "ms5": experiment_level_5
}

# %%
plot_aggregated_metrics_by_type(experiment_levels, layer_names, metric="effective_rank")

# %%
plot_aggregated_metrics_by_type(experiment_levels, layer_names, max_components=100, center=True, metric="cum_explained")
